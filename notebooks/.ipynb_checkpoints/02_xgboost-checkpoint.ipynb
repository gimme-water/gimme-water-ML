# %%
import xgboost as xgb
from pandas import read_csv
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %%
df = read_csv('./agg.csv')
x_cols = ['Ta', 'Rh', 'R', 'CO2']
y_col = 'Tl'

df.head()
# Out:
#    Unnamed: 0         DateTime_start         Ta         Rh    R         CO2  \
# 0           0  2021-03-09T00:08:30.0  22.536364  80.363636  0.0  416.272727
# 1           1  2021-03-09T00:18:30.0  22.600000  79.563636  0.0  416.909091
# 2           2  2021-03-09T00:28:30.0  22.618182  80.581818  0.0  415.818182
# 3           3  2021-03-09T00:38:30.0  22.700000  79.018182  0.0  416.090909
# 4           4  2021-03-09T00:48:30.0  22.663636  79.954545  0.0  415.909091
#
#           Tl
# 0  25.836832
# 1  26.256781
# 2  25.955940
# 3  25.710634
# 4  25.644834

# %%
X = df[x_cols]
y = df[y_col]

# 시계열 데이터이므로 순서를 유지하며 Train/Test 분할
train_size = int(len(X) * 0.8)
X_train, X_test = X.iloc[:train_size], X.iloc[train_size:]
y_train, y_test = y.iloc[:train_size], y.iloc[train_size:]

# %%
# XGBoost 모델 생성 및 학습
model_xgb = xgb.XGBRegressor(
    n_estimators=1000,
    learning_rate=0.05,
    max_depth=5,
    n_jobs=-1,
    early_stopping_rounds=50,
    verbosity=1
)

model_xgb.fit(
    X_train, y_train,
    eval_set=[(X_test, y_test)],
    verbose=False
)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=1000,
#              n_jobs=-1, num_parallel_tree=None, ...)

# %%
y_pred = model_xgb.predict(X_test)
print(f"R2 Score: {r2_score(y_test, y_pred):.4f}")
print(f"RMSE: {mean_squared_error(y_test, y_pred):.4f}")
# Out:
# R2 Score: 0.8890
# RMSE: 5.5355

# %%
#일단 StandarScaling을 통해서 0과 가까운 값으로 통일을 하지 않았음에도 불구하고 이정도면 그렇게 나쁘지는 않다고 보임.
#그냥 XGBoost만 쓴게 이정도니까 일단 더 분석을 해보고 finetuning을 이것 저것 해보면 될 것 같다.
#재미있게도 시계열 데이터의 특성을 오히려 반영하지 않은, Seasonality를 고려하지 않은게 더 성능이 좋다는것.
#아마 Seanonality가 실제로 아래에도 그렇게 보이지 않는다는 것을 감안하면 사실 그렇게 문제가 되는 것은 아닌 것 같다.

plt.figure(figsize=(15, 6))
plt.plot(y_test.index, y_test.values, label='Actual Tl', alpha=0.6, color='blue')
plt.plot(y_test.index, y_pred, label='XGBoost Pred', alpha=0.7, color='red')
plt.title('XGBoost: Actual vs Predicted (Test Set)')
plt.legend()
plt.show()
